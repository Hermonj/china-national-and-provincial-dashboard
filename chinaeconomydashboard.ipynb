# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Hermonj/china-national-and-provincial-dashboard/master/data/Economy_Dashboard3.csv')
df
# Out:
#       YEAR  GDP growth  Inflation rate  Implied PPP conversion rate  \
# 0   1980.0         7.9             2.0                        1.500
# 1   1981.0         5.1             2.5                        1.413
# 2   1982.0         9.0             2.0                        1.336
# 3   1983.0        10.8             2.0                        1.300
# 4   1984.0        15.2             2.7                        1.316
# 5   1985.0        13.5             9.3                        1.404
# 6   1986.0         8.9             6.5                        1.442
# 7   1987.0        11.7             7.3                        1.479
# 8   1988.0        11.2            18.8                        1.602
# 9   1989.0         4.2            18.0                        1.678
# 10  1990.0         3.9             3.1                        1.712
# 11  1991.0         9.0             3.4                        1.762
# 12  1992.0        14.3             6.4                        1.859
# ...

# %%
from matplotlib import pyplot as plt
df['Implied PPP conversion rate'].plot(kind='hist', bins=20, title='Implied PPP conversion rate')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='YEAR', y='GDP growth', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Hermonj/china-national-and-provincial-dashboard/master/data/GDP%20by%20national%20currency%20(renminbi)%20in%20main%20years.csv')
df
# Out:
#                 year        2021        2020       2015       2010       2000
# 0   China?(mainland)  114,923.70  101,356.70  68,885.82  41,211.93  10,028.01
# 1          Guangdong   12,471.95   11,115.16   7,473.24   4,594.46   1,081.02
# 2            Jiangsu   11,739.24   10,280.77   7,125.59   4,138.39     855.37
# 3           Shandong    8,287.52    7,279.82   5,528.88   3,392.25     827.81
# 4           Zhejiang    7,404.08    6,468.91   4,350.77   2,739.99     616.48
# 5              Henan    5,807.14    5,425.94   3,708.41   2,265.50      505.3
# 6            Sichuan    5,408.80    4,850.16   3,034.20   1,722.48     392.82
# 7              Hubei    5,009.12    4,300.45   3,034.40   1,622.69     354.54
# 8             Fujian    4,956.61    4,360.86   2,681.95   1,500.25     376.45
# 9              Hunan    4,571.35    4,154.26   2,853.86   1,557.43     355.15
# 10          Shanghai    4,365.32    3,896.33   2,688.70   1,791.54     481.22
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['year']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'year'}, axis=1)
              .sort_values('year', ascending=True))
  xs = counted['year']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('year')
_ = plt.ylabel('count()')

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Hermonj/china-national-and-provincial-dashboard/master/data/Average%20annual%20exchange%20rate%20in%202022%20CNY%206.7261%20per%20U.S.%20dollar.csv')
df
# Out:
#     Rank         Provinces    GDP (CN)   GDP (US)  \
# 0      0  China (Mainland)  121,020.72  17,992.70
# 1      1         Guangdong   12,911.86   1,919.67
# 2      2           Jiangsu   12,287.56   1,826.85
# 3      3          Shandong    8,743.51   1,299.94
# 4      4          Zhejiang    7,771.54   1,155.43
# 5      5             Henan    6,134.51     912.05
# 6      6           Sichuan    5,674.98     843.73
# 7      7             Hubei    5,373.49      798.9
# 8      8            Fujian    5,310.99     789.61
# 9      9             Hunan    4,867.04     723.61
# 10    10             Anhui    4,504.50      669.7
# 11    11          Shanghai    4,465.28     663.87
# 12    12             Hebei    4,237.04     629.94
# 13    13           Beijing    4,161.10     618.65
# 14    14           Shaanxi    3,277.27     487.25
# 15    15           Jiangxi    3,207.47     476.87
# 16    16         Chongqing    2,912.90     433.07
# 17    17          Liaoning    2,897.51     430.79
# ...

# %%
from matplotlib import pyplot as plt
df['Real growth (%)'].plot(kind='line', figsize=(8, 4), title='Real growth (%)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Rank']
  ys = series['Real growth (%)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Rank', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Rank')
_ = plt.ylabel('Real growth (%)')

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Growth at current prices (%)', y='Real growth (%)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Real growth (%)'].plot(kind='hist', bins=20, title='Real growth (%)')
plt.gca().spines[['top', 'right',]].set_visible(False)
